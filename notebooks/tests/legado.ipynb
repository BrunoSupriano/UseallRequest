# %%
import pandas as pd
import requests

useallitens = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOFIM%22%2C%20%22Valor%22%3A%20%2227%2F02%2F2024%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_estoque_item"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallitens = requests.get(useallitens, headers=headers)

datauseallitens = responseuseallitens.json()
dfuseallitens = pd.DataFrame(datauseallitens)
dfuseallitens.head()
# Out:
#    IDITEM    DATAHORAALTERACAO IDENTIFICACAO  \
# 0  463268  2024-02-22T23:22:03         28286
# 1  407012  2023-01-26T16:04:57        434777
# 2  406785  2023-01-31T11:41:15        434597
# 3  406724  2023-03-28T17:42:13         18040
# 4  406262  2023-01-26T15:03:17        434358
#
#                                            DESCRICAO  IDCLASSFISCAL  IDUN  \
# 0                          CABO FLEXIVEL 1,5 BRANCO          688619  1838
# 1  CASCATA RED 40CM P/05 LAMP. GU10 DNA 1,4M DNA4...         683769  1818
# 2  LUSTRE SÃO PETERSBURGO 5 BRAÇOS METAL Ø54X58 B...         683769  1818
# 3                SAPATO SOCIAL COM CADARÇO N37 PRETO         689382  1833
# 4  PENDENTE CABO PORTA LÂMPADAS HANG 5500MM IP65 ...         683769  1818
#
#    IDUNVENDA  QUANTEMBVENDA  PESOBRUTO  PESOLIQ   OBS  ATIVO COMPLEMENTO  \
# 0     1838.0            1.0        0.0      0.0  None      0        None
# 1     1818.0            0.0        0.0      0.0  None      0        None
# ...

# %%
useallunidades = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOFIM%22%2C%20%22Valor%22%3A%20%2227%2F02%2F2024%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_estoque_unidade"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallunidades = requests.get(useallunidades, headers=headers)

datauseallunidades = responseuseallunidades.json()
dfuseallunidades = pd.DataFrame(datauseallunidades)
dfuseallunidades.head()
# Out:
#    IDUN  IDUNIDADETENANT       DESCRICAO SIGLA SIGLAFCI    DATAHORAALTERACAO  \
# 0  1818                1         UNIDADE    UN       UN  2022-09-23T11:46:05
# 1  1819                2           CAIXA    CX       CX  1900-01-01T00:00:00
# 2  1821                4           GRAMA     G        G  1900-01-01T00:00:00
# 3  1822                5      QUILOGRAMA    KG       KG  1900-01-01T00:00:00
# 4  1823                6  METRO QUADRADO    M2       M2  1900-01-01T00:00:00
#
#   STATUS
# 0  Ativo
# 1  Ativo
# 2  Ativo
# 3  Ativo
# 4  Ativo

# %%
useallsegmentos = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOFIM%22%2C%20%22Valor%22%3A%20%2227%2F02%2F2024%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_vendas_segmento"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallsegmentos = requests.get(useallsegmentos, headers=headers)

datauseallsegmentos = responseuseallsegmentos.json()
dfuseallsegmentos = pd.DataFrame(datauseallsegmentos)
dfuseallsegmentos.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
useallcidades = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOFIM%22%2C%20%22Valor%22%3A%20%2227%2F02%2F2024%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_geral_cidades"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallcidades = requests.get(useallcidades, headers=headers)

datauseallcidades = responseuseallcidades.json()
dfuseallcidades = pd.DataFrame(datauseallcidades)
dfuseallcidades.head()
# Out:
#    IDCIDADE    DATAHORAALTERACAO              NOME  MUNICIPIO_IBGE  IDNFSE  \
# 0      5565  1900-01-01T00:00:00  Balneário Rincão         4220000  5613.0
# 1      5566  1900-01-01T00:00:00    NAO CADASTRADO               0     NaN
# 2      5567  2018-11-08T17:42:17    Pescaria Brava         4212650  5614.0
# 3    268416  1900-01-01T00:00:00     Praia de Fora         9999999     NaN
# 4    268482  1900-01-01T00:00:00            Sangao         4215455     NaN
#
#    CODIGORFB          DATAHORACAD  CODIBGE SIGLA
# 0     1192.0  1900-01-01T00:00:00       42    SC
# 1     9707.0  1900-01-01T00:00:00       42    SC
# 2     1194.0  2018-11-08T17:42:02       42    SC
# 3        NaN  1900-01-01T00:00:00       42    SC
# 4        NaN  1900-01-01T00:00:00       42    SC

# %%
useallsolcompra = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%7B%20%22Nome%22%3A%20%22DataFim%22%2C%20%22Valor%22%3A%20%2201%2F01%2F2500%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_compras_m2_compras_solicitacao_de_compras__extra"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallsolcompra = requests.get(useallsolcompra, headers=headers)

datauseallsolcompra = responseuseallsolcompra.json()
dfuseallsolcompra = pd.DataFrame(datauseallsolcompra)
dfuseallsolcompra.head()
# Out:
#    IDSOLICCOMPRA  IDEMPRESA  IDFILIAL  NUMERO  IDSOLICITANTE   OBS    STATUS  \
# 0          20254        211       334     118        1652272  None  Liberado
# 1          20254        211       334     118        1652272  None  Liberado
# 2          20254        211       334     118        1652272  None  Liberado
# 3          20254        211       334     118        1652272  None  Liberado
# 4          20254        211       334     118        1652272  None  Liberado
#
#   PRIMEIRADATANECESSIDADE                        FINALIDADE  \
# 0     2019-07-08T00:00:00  Matéria-prima (Industrialização)
# 1     2019-07-08T00:00:00  Matéria-prima (Industrialização)
# 2     2019-07-08T00:00:00  Matéria-prima (Industrialização)
# 3     2019-07-08T00:00:00  Matéria-prima (Industrialização)
# 4     2019-07-08T00:00:00  Matéria-prima (Industrialização)
#
#    IDSOLICCOMPRAITEM  ...  IDUN  QUANT      DATANECESSIDADE COMPLEMENTO SALDO  \
# ...

# %%
useallfiliais = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22DATAHORAALTINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%2C%2011%3A00%3A00%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAHORAALTFIM%22%2C%20%22Valor%22%3A%20%2201%2F01%2F2500%2C%2014%3A00%3A00%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_geral_filiais"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallfiliais = requests.get(useallfiliais, headers=headers)

datauseallfiliais = responseuseallfiliais.json()
dfuseallfiliais = pd.DataFrame(datauseallfiliais)
dfuseallfiliais.head()
# Out:
#    IDFILIAL          DATAHORAALT  IDEMPRESA  MATRIZ  \
# 0       379  2025-07-03T08:55:51        211       0
# 1       381  2025-09-10T13:58:35        242       1
# 2       387  2025-08-14T16:18:20        211       0
# 3       333  2026-01-05T17:13:43        211       1
# 4       338  2023-05-03T10:38:49        212       1
#
#                               APELIDO
# 0  SETUP MATRIZ (ENDEREÇO DE ENTREGA)
# 1  ENGECO PROJETOS E CONSTRUCOES LTDA
# 2                       SETUP PELOTAS
# 3         SETUP AUTOMACAO E SEGURANCA
# 4                        WFF COMERCIO

# %%
useallempresas = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22DATAHORAALTINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F2022%2C%2011%3A00%3A00%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAHORAALTFIM%22%2C%20%22Valor%22%3A%20%2226%2F02%2F2024%2C%2014%3A00%3A00%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_geral_empresas"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallempresas = requests.get(useallempresas, headers=headers)

datauseallempresas = responseuseallempresas.json()
dfuseallempresas = pd.DataFrame(datauseallempresas)
dfuseallempresas.head()
# Out:
#    IDEMPRESA          DATAHORAALT         CNPJCPF  \
# 0        214  2022-10-10T11:27:35  15019484000198
# 1        215  2023-03-27T17:39:31  34381213000122
# 2        216  2022-06-14T15:48:17  34306437000170
# 3        249  2023-04-25T18:07:06  48858342000173
#
#                                          RAZAOSOCIAL  \
# 0                            VIGILANCIA SETUP EIRELI
# 1                    SETUP COMERCIO DE PRODUTOS LTDA
# 2  VM COMÉRCIO E DISTRIBUIÇÃO DE MATERIAIS ELÉTRI...
# 3                    FFW ADMINISTRADORA DE BENS LTDA
#
#                       NOMEFANTASIA         IE     IM  \
# 0                SETUP VIGILANCIA   256635404  43949
# 1                   SETUP COMERCIO  260177164
# 2                               VM  260168084
# 3  FFW ADMINISTRADORA DE BENS LTDA       None   None
#
#                        ENDERECO          BAIRRO       CEP        FONE   FAX  \
# 0             RUA SAO MARTINHO,   UNIVERSITARIO  88805360  4899241469  None
# ...

# %%
useallexpedição = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22data1%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22data2%22%2C%20%22Valor%22%3A%20%2201%2F01%2F2500%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_vendas_extracao_de_dados__saida_expedicao"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallexpedição = requests.get(useallexpedição, headers=headers)

datauseallexpedição = responseuseallexpedição.json()
dfuseallexpedição = pd.DataFrame(datauseallexpedição)
dfuseallexpedição.head()
# Out:
#    CODIGOFAT          DATAHORACAD          DATAENTREGA CONFERENCIA  \
# 0    4963764  2024-06-18T12:11:58  0001-01-01T00:00:00    INICIADA
# 1    4994034  2024-06-24T13:42:44  0001-01-01T00:00:00    INICIADA
# 2    4994217  2024-06-24T13:47:18  0001-01-01T00:00:00    INICIADA
# 3    4994277  2024-06-24T13:50:34  0001-01-01T00:00:00    INICIADA
# 4    4994258  2024-06-24T13:50:34  0001-01-01T00:00:00    INICIADA
#
#    ORIGEMCONFERENCIA DESCRICAOORIGEMCONFERENCIA  ORIGEM  CODIGOOIRIGEM  \
# 0                0.0                     MANUAL  MANUAL              0
# 1                0.0                     MANUAL  MANUAL              0
# 2                0.0                     MANUAL  MANUAL              0
# 3                0.0                     MANUAL  MANUAL              0
# 4                0.0                     MANUAL  MANUAL              0
#
#    NUMERODOC NUMEROPEDIDOCLIENTE  ...  ORDEM CODIGOFILIAL CODIGOEMPRESA PLACA  \
# ...

# %%
# List all DataFrames loaded in memory
dfs = {
    'dfuseallitens': dfuseallitens,
    'dfuseallunidades': dfuseallunidades,
    'dfuseallsegmentos': dfuseallsegmentos,
    'dfuseallcidades': dfuseallcidades,
    'dfuseallsolcompra': dfuseallsolcompra,
    'dfuseallfiliais': dfuseallfiliais,
    'dfuseallempresas': dfuseallempresas,
    'dfuseallexpedição': dfuseallexpedição
}

# gere um .parquet para cada DataFrame
for name, df in dfs.items():
    df.to_parquet(f'{name}.parquet', index=False)

# %%
useallclientesfornecedore = "https://extracao.useallcloud.com.br/api/v1/json/?FiltrosSqlQuery=%5B%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOINI%22%2C%20%22Valor%22%3A%20%2201%2F01%2F1900%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%2C%20%7B%20%22Nome%22%3A%20%22DATAHORAALTERACAOFIM%22%2C%20%22Valor%22%3A%20%2227%2F02%2F2024%22%2C%20%22Operador%22%3A%20null%2C%20%22Descricao%22%3A%20null%2C%20%22ValorFormatado%22%3A%20null%20%7D%5D&pagina=1&qtderegistros=1&Identificacao=m2_geral_clientes__fornecedores"

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallclientesfornecedore = requests.get(useallclientesfornecedore, headers=headers)

if responseuseallclientesfornecedore.status_code == 200:
    datauseallclientesfornecedore = responseuseallclientesfornecedore.json()
    dfuseallclientesfornecedore = pd.DataFrame(datauseallclientesfornecedore)
    print(f"Successfully loaded clients/suppliers data. Shape: {dfuseallclientesfornecedore.shape}")
    dfuseallclientesfornecedore.head()
else:
    print(f"Error: API returned status code {responseuseallclientesfornecedore.status_code}")
    print(f"Response: {responseuseallclientesfornecedore.text}")
    dfuseallclientesfornecedore = pd.DataFrame()
# Out:
# Successfully loaded clients/suppliers data. Shape: (23163, 54)

# %%
import json
import urllib.parse
import requests
import pandas as pd

BASE_URL = "https://extracao.useallcloud.com.br/api/v1/json/"

filtros_sql = [
    {
        "Nome": "IDFILIAL",
        "Valor": [333,334,335,336,387,404,520,558,578,339,340,342,343,341,344,345,346,381,389,390],
        "Operador": 1,
        "Descricao": "Filial",
        "ValorFormatado": "SETUP AUTOMACAO E SEGURANCA",
        "TipoPeriodoData": None
    },
    {
        "Nome": "DATA",
        "Valor": "01/01/1900,01/01/2900",
        "Operador": 8,
        "Descricao": "Data da requisição",
        "ValorFormatado": "01/01/1900 até 01/01/2900",
        "TipoPeriodoData": 1
    },
    {
        "Nome": "DATAPREVATEND",
        "Valor": "01/01/1900,01/01/2900",
        "Operador": 8,
        "Descricao": "Previsão atendimento",
        "ValorFormatado": "01/01/1900 até 01/01/2900",
        "TipoPeriodoData": 1
    },
    {"Nome": "CLASSGRUPOITEM", "Valor": ""},
    {"Nome": "CLASSCONTACDC", "Valor": ""},
    {"Nome": "quebra", "Valor": 0},
    {
        "Nome": "FILTROSWHERE",
        "Valor": " AND IDEMPRESA = 211"
    }
]

filtros_json = json.dumps(filtros_sql, ensure_ascii=False)
filtros_encoded = urllib.parse.quote(filtros_json)

useallrequisicoes = (
    f"{BASE_URL}"
    f"?Identificacao=m2_estoque_requisicao_de_materiais"
    f"&FiltrosSqlQuery={filtros_encoded}"
)

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

responseuseallrequisicoes = requests.get(
    useallrequisicoes,
    headers=headers,
    timeout=60
)

if responseuseallrequisicoes.status_code == 200:
    datauseallrequisicoes = responseuseallrequisicoes.json()
    dfuseallrequisicoes = pd.DataFrame(datauseallrequisicoes)
    print(f"Loaded successfully. Shape: {dfuseallrequisicoes.shape}")
else:
    print("Erro:", responseuseallrequisicoes.status_code)
    print(responseuseallrequisicoes.text)
    dfuseallrequisicoes = pd.DataFrame()

dfuseallrequisicoes.to_parquet('dfuseallrequisicoes.parquet', index=False)
# Out:
# Loaded successfully. Shape: (675820, 39)

# %%
import json
import urllib.parse
import requests
import pandas as pd

BASE_URL = "https://extracao.useallcloud.com.br/api/v1/json/"

filtros_sql = [
    {
        "Nome": "ADDATA",
        "Valor": "08/01/2026"
    },
    {
        "Nome": "FILTROSWHERE",
        "Valor": (
            " AND EXISTS ("
            "SELECT 1 FROM USE_USUARIOS_FILIAIS UFILIAIS "
            "WHERE UFILIAIS.IDEMPRESA = T.IDEMPRESA "
            "AND UFILIAIS.IDFILIAL = T.IDFILIAL "
            "AND UFILIAIS.IDUSUARIO = 7332"
            ") "
            "AND T.IDFILIAL IN (333,334,336,404,335,387,520,558,578)"
        )
    },
    {
        "Nome": "ANQUEBRA",
        "Valor": 0
    }
]

filtros_json = json.dumps(filtros_sql, ensure_ascii=False)
filtros_encoded = urllib.parse.quote(filtros_json)

useallestoque = (
    f"{BASE_URL}"
    f"?Identificacao=09249662000174_m2_estoque_saldo_de_estoque__setup"
    f"&FiltrosSqlQuery={filtros_encoded}"
)

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

response = requests.get(
    useallestoque,
    headers=headers,
    timeout=60
)

if response.status_code == 200:
    datauseallestoque = response.json()
    dfuseallestoque = pd.DataFrame(datauseallestoque)
    print(f"Loaded successfully. Shape: {dfuseallestoque.shape}")
else:
    print("Erro:", response.status_code)
    print(response.text)
    dfuseallestoque = pd.DataFrame()

dfuseallestoque.to_parquet('dfuseallestoque.parquet', index=False)
# Out:
# Loaded successfully. Shape: (132495, 24)

# %%
import requests
import urllib.parse
import json

base_url = "https://extracao.useallcloud.com.br/api/v1/json"

filtros_sql_query = json.dumps([
    {
        "Nome": "FILTROSWHERE",
        "Valor": (
            "WHERE IDEMPRESA = 211 "
            "AND IDFILIAL IN (333,334,335,336,387,404,520,558,339,578,340,342,343,341,344,345,346,381,389,390) "
            "AND DATA_REQ >= '01/01/1900' AND DATA_REQ <= '01/01/2900' "
            "AND DATA_ATEND >= '01/01/1900' AND DATA_ATEND <= '01/01/2900'"
        )
    }
])

params = {
    "Identificacao": "m2_estoque_atendimentos_de_requisicao",
    "NomeOrganizacao": "SETUP SERVICOS ESPECIALIZADOS LTDA",
    "Parametros": json.dumps([
        {"Nome": "usecellmerging", "Valor": True},
        {"Nome": "quebra", "Valor": 0},
        {
            "Nome": "filter",
            "Valor": (
                "Filial: SETUP AUTOMACAO E SEGURANCA, LOJA - ARARANGUA, LOJA - CRICIUMA\n"
                "Data requisição: 01/01/1900 até 01/01/2900\n"
                "Data atendimento: 01/01/1900 até 01/01/2900"
            )
        }
    ]),
    "FiltrosSqlQuery": filtros_sql_query
}

headers = {
    "accept": "application/json",
    "use-relatorio-token": "eyJJZCI6ImNkMDNkMzhiLWZhNzUtNDg4Yi04NDA1LTg5OTU1MzBjNjFiMSIsIlN0cmluZ0NvbmV4YW8iOiJBeHh4IFh2a2VqST10bGRxZGZ4Rzk7c3FJMSBCbz1ScUl4WHlnYWVoO2dNcXp6djFvPXNxSXVleGd5SW5TSSQkOyIsIkNvZGlnb1VzdWFyaW8iOjczMzIsIkNvZGlnb1RlbmFudCI6MTQzfQ=="
}

url_final = f"{base_url}?{urllib.parse.urlencode(params)}"

response = requests.get(url_final, headers=headers)
response.raise_for_status()

dados = response.json()

import pandas as pd
datauseallatendimentodereq = dados

dfuseallatendimentodereq = pd.DataFrame(datauseallatendimentodereq)

dfuseallatendimentodereq.to_parquet('dfuseallatendimentodereq.parquet', index=False)

# %%
# extrair o extrato de estoque - fim

# Extrato de estoque não tem de todos de uma vez tem que passar item por item, vai ser bem demorado, ja que tem 3min de limite por consulta... verificar com Alan a necessidade dessa informação
